# %% [markdown]
# # First 10 rows of raw dataset

# %%
import pandas as pd
import numpy as np
pf = pd.read_csv("https://data.wprdc.org/datastore/dump/fbb50b02-2879-47cd-abea-ae697ec05170") 
print(pf)
# Out:
#              id  parcel_id inactive  \
# 0     650726265  120-J-300        f
# 1     783044037    2-H-284        f
# 2    1997158435   23-R-157        f
# 3     204824684   10-F-198        f
# 4     472140955  013-K-314        f
# ..          ...        ...      ...
# 402   803210807    36-L-81      NaN
# 403   502777164    36-L-81      NaN
# 404  1440497844  125-N-200      NaN
# 405   338803846  125-N-200      NaN
# 406  1111447104  231-S-600      NaN
#
#                                                   name rentable     type  \
# 0                            57th Street Park Building        f  Storage
# 1                      Albert Turk Graham Park Shelter        f  Shelter
# 2    Allegheny Northside Senior Center and Hazlett ...        t   Senior
# 3                              Ammon Recreation Center        f     Pool
# 4                      Arlington Field Lights Building        f  Utility
# ..                                                 ...      ...      ...
# 402            Banksville School Field 3rd Base Dugout        f   Dugout
# 403           Banksville School Field Storage Building        f  Storage
# 404                Mellon Park Field 2 1st Base Dugout        f   Dugout
# 405                Mellon Park Field 2 3rd Base Dugout        f   Dugout
# 406                            East Hills Park Shelter        f  Shelter
#
#                    primary_user  address_number          street      zip  ...  \
# 0    Department of Public Works             NaN         57TH ST      NaN  ...
# 1    Department of Public Works            39.0         VINE ST      NaN  ...
# 2                     CitiParks             5.0  ALLEGHENY SQ E  15212.0  ...
# 3                     CitiParks          2217.0     BEDFORD AVE  15219.0  ...
# 4                     CitiParks             0.0     STERLING ST  15210.0  ...
# ..                          ...             ...             ...      ...  ...
# 402  Department of Public Works             NaN     CARNAHAN RD      NaN  ...
# 403  Department of Public Works             NaN     CARNAHAN RD      NaN  ...
# 404  Department of Public Works             NaN       PUTNAM ST      NaN  ...
# 405  Department of Public Works             NaN       PUTNAM ST      NaN  ...
# 406  Department of Public Works             NaN       WILNER DR  15221.0  ...
#
#             neighborhood council_district  ward        tract  \
# 0    Upper Lawrenceville                7  10.0  42003101100
# 1       Crawford-Roberts                6   3.0  42003030500
# 2       Allegheny Center                1  22.0  42003562700
# 3      Bedford Dwellings                6   5.0  42003050900
# 4      South Side Slopes                3  16.0  42003160800
# ..                   ...              ...   ...          ...
# 402           Banksville                2  20.0  42003202300
# 403           Banksville                2  20.0  42003202300
# 404            Shadyside                8   7.0  42003070800
# 405            Shadyside                8   7.0  42003070800
# 406           East Hills                9  13.0  42003130600
#
#      public_works_division  pli_division  police_zone  fire_zone   latitude  \
# 0                      2.0          10.0          2.0        3-5  40.485658
# 1                      3.0           3.0          2.0        2-1  40.440464
# 2                      1.0          22.0          1.0        1-6  40.453091
# 3                      3.0           5.0          2.0        2-5  40.448727
# 4                      3.0          16.0          3.0       4-22  40.418144
# ..                     ...           ...          ...        ...        ...
# 402                    5.0          20.0          6.0        4-9  40.407140
# 403                    5.0          20.0          6.0        4-9  40.407314
# 404                    2.0           7.0          4.0       3-13  40.455754
# 405                    2.0           7.0          4.0       3-13  40.455785
# 406                    2.0          13.0          5.0       3-19  40.453975
#
#      longitude
# 0   -79.946446
# 1   -79.984103
# 2   -80.005339
# 3   -79.977853
# 4   -79.974468
# ..         ...
# 402 -80.037516
# 403 -80.038099
# 404 -79.915588
# 405 -79.915420
# 406 -79.871408
#
# [407 rows x 21 columns]

# %% [markdown]
# # Number of public facilities by neighborhood

# %%
neighborhoods = pf['neighborhood'].value_counts()
print(neighborhoods)
# Out:
# Highland Park           30
# Squirrel Hill South     29
# Perry North             20
# Brookline               19
# Strip District          15
#                         ..
# Fineview                 1
# Fairywood                1
# Central Oakland          1
# California-Kirkbride     1
# Middle Hill              1
# Name: neighborhood, Length: 75, dtype: int64

# %% [markdown]
# # Graph of Public Facilities by neighborhood

# %%
neighborhoods.plot(kind = 'bar', figsize = (75,30))
